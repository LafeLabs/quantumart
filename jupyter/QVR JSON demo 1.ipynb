# %%
import numpy as np

# %%
phi = np.linspace(0, 6*np.pi, 100)
theta = np.linspace(0,0.05*np.pi,100)
print("[")
index = 0;
for foo in theta:
    print("{\"theta\":[" + str(theta[index]) + '],')
    print("\"phi\":[" + str(phi[index]) + ']')
    if(index != len(theta) - 1):
        print("},")
    else:
        print("}]")
    index = index + 1
# Out:
# [
# {"theta":[0.0],
# "phi":[0.0]
# },
# {"theta":[0.0015866629563584813],
# "phi":[0.19039955476301776]
# },
# {"theta":[0.0031733259127169626],
# "phi":[0.3807991095260355]
# },
# {"theta":[0.004759988869075444],
# "phi":[0.5711986642890533]
# },
# {"theta":[0.006346651825433925],
# "phi":[0.761598219052071]
# },
# {"theta":[0.007933314781792407],
# "phi":[0.9519977738150888]
# },
# {"theta":[0.009519977738150888],
# "phi":[1.1423973285781066]
# },
# {"theta":[0.01110664069450937],
# "phi":[1.3327968833411243]
# },
# {"theta":[0.01269330365086785],
# "phi":[1.523196438104142]
# },
# {"theta":[0.014279966607226332],
# "phi":[1.7135959928671598]
# },
# {"theta":[0.015866629563584814],
# "phi":[1.9039955476301775]
# },
# {"theta":[0.017453292519943295],
# "phi":[2.0943951023931953]
# },
# {"theta":[0.019039955476301777],
# "phi":[2.284794657156213]
# },
# {"theta":[0.020626618432660258],
# "phi":[2.4751942119192307]
# },
# {"theta":[0.02221328138901874],
# "phi":[2.6655937666822487]
# ...

# %% [markdown]
# For n qubits, there are $2^N$ states.  In quantum geometron, there is always a "current state", on which operations take place.  There is a correlation between the current state, the current $\theta$ angle and the current phase.
#
# Operations in this language include:
#
# - move to next state/angle/phase
# - move to previous state/angle
# - connect current state $\theta$ angle to current rotation angle in 3d structure
# - connect current state $\phi$ phase angle to current rotation angle in 3d structure
# - connect current amplitude squared $a^2$ to current shape opacity in 3d structures
# - connect current amplitude squared $a^2$ to current shape size scale in 3d structures

# %% [markdown]
# What now?  Conversion from an array of arrays of amplitudes into an array of angles, in python, which outputs a string of the final JSON.  We must be able to take the standard formats from ibm, msft, rigetti, qtip and convert via python into JSON text.
